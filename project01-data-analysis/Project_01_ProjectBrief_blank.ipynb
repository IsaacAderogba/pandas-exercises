# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("movies_complete.csv", parse_dates=["release_date"])

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.info() # no need to handle or remove missing values, because that's what we'll be using pandas for
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
# id                       44691 non-null int64
# title                    44691 non-null object
# tagline                  20284 non-null object
# release_date             44657 non-null datetime64[ns]
# genres                   42586 non-null object
# belongs_to_collection    4463 non-null object
# original_language        44681 non-null object
# budget_musd              8854 non-null float64
# revenue_musd             7385 non-null float64
# production_companies     33356 non-null object
# production_countries     38835 non-null object
# vote_count               44691 non-null float64
# vote_average             42077 non-null float64
# popularity               44691 non-null float64
# runtime                  43179 non-null float64
# overview                 43740 non-null object
# spoken_languages         41094 non-null object
# ...

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
# visualise frequency distributions using a histogram
df.hist(figsize = (20, 12), bins = 100)
plt.show()

# %%
df.budget_musd.value_counts(dropna=False).head(20) # essentially the 20 most frequent values
# Out:
# nan      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 0.50       141
# 35.00      141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64

# %%
df.revenue_musd.value_counts(dropna=False).head(20) # essentially the 20 most frequent values - should bucket these
# Out:
# nan      37306
# 12.00       20
# 11.00       19
# 10.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 20.00       10
# 1.00        10
# 4.00         9
# 0.00         9
# 1.50         9
# 25.00        8
# 16.00        8
# Name: revenue_musd, dtype: int64

# %%
df.vote_average.value_counts(dropna=False)
# Out:
# nan     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
#         ...
# 9.40       3
# 9.80       1
# 0.70       1
# 1.10       1
# 9.60       1
# Name: vote_average, Length: 93, dtype: int64

# %%
df.vote_count.value_counts(dropna=False)
# Out:
# 1.00       3186
# 2.00       3056
# 3.00       2729
# 0.00       2614
# 4.00       2442
#            ...
# 4461.00       1
# 1085.00       1
# 1539.00       1
# 2487.00       1
# 3086.00       1
# Name: vote_count, Length: 1820, dtype: int64

# %%
df.describe(include = "object") # wasn't aware of this
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
df[df.title == "Cinderella"] # different movies with the same title
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# ### The Best and the Worst Movies

# %%
from IPython.display import HTML # allows display in high quality website-like format

# %%
# create seperate dataframe

df_best = df[["poster_path", "title", "budget_musd", "revenue_musd", "vote_count", "vote_average", "popularity"]].copy()
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
# absolute profit (revenue - budget)
# roi (revenue / budget)
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["return"] = df.revenue_musd.div(df.budget_musd)
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
# renaming of labels
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes", "Average Rating", "Popularity", "Profit", "ROI"]

# %%
df_best
# Out:
#                                                           \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              Title  Budget  Revenue   Votes  Average Rating  \
# 0                        Toy Story   30.00   373.55 5415.00            7.70
# 1                          Jumanji   65.00   262.80 2413.00            6.90
# ...

# %%
# change the index to be the title column
df_best.set_index("Title", inplace=True)

# %%
df_best
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %%
df_best.iloc[0, 0] # disregards the index - we can get the images here themselves
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
subset = df_best.iloc[:5, :2] # up to 5, up to 2

# %%
subset
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                              Budget
# Title
# Toy Story                     30.00
# Jumanji                       65.00
# Grumpier Old Men                nan
# Waiting to Exhale             16.00
# Father of the Bride Part II     nan

# %%
HTML(subset.to_html(escape=False)) # no more html code oh wow
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>nan</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %%
df_best.sort_values(by="Average Rating", ascending=False)
# Out:
#                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2...
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifP...
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOc...
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH...
# ...                                                                                       ...
# Altar of Fire                               <img src='http://image.tmdb.org/t/p/w185//iJ78...
# The Wonders of Aladdin                      <img src='http://image.tmdb.org/t/p/w185//AvfX...
# Deep Hearts                                 <img src='http://image.tmdb.org/t/p/w185//8jI4...
# ...

# %%
df_best.sort_values(by="ROI", ascending=False)
# Out:
#                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0...
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoi...
# Welcome to Dongmakgol    <img src='http://image.tmdb.org/t/p/w185//5iGV...
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflx...
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne...
# ...                                                                    ...
# Subdue                   <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing      <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                 <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant         <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                 <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %%
# filter with budget greater and then sort
df_best.loc[df_best.Budget >= 5].sort_values(by = "ROI", ascending=False)
# Out:
#                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfk...
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2...
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xc...
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwO...
# ...                                                                                           ...
# The Blonde with Bare Breasts                    <img src='http://image.tmdb.org/t/p/w185//zBjp...
# Detroit                                         <img src='http://image.tmdb.org/t/p/w185//7APL...
# ...

# %%
df_best.Budget.fillna(0, inplace=True)
df_best.Votes.fillna(0, inplace=True)

# %%
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 8 columns):
#                   44467 non-null object
# Budget            44691 non-null float64
# Revenue           7385 non-null float64
# Votes             44691 non-null float64
# Average Rating    42077 non-null float64
# Popularity        44691 non-null float64
# Profit            5371 non-null float64
# ROI               5371 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 4.3+ MB

# %%
# best and worst n movies
def best_worst(n, by, ascending=False, min_bud=0, min_votes = 0):
    
    df2 = df_best.loc[(df_best.Budget >= min_bud) & (df_best.Votes >= min_votes), ["", by]].sort_values(by=by, ascending=ascending).head(n).copy()
    
    return HTML(df2.to_html(escape=False))

# %%
best_worst(n=5, by="Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %%
best_worst(n=5, by="Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %%
best_worst(n=5, by="Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %%
best_worst(5, "Profit", ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %%
best_worst(5, "ROI", min_bud=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
# ...

# %%
best_worst(5, "ROI", ascending=True, min_bud=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Chasing Liberty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7qzvS9QKkiDcz1K8EY9Y6ZXkUeD.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>The Adventurer: The Curse of the Midas Box</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//31ykUoOS2RNdARk3B8z3y25gD8b.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Chaos</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wSZYVssIv4kjRJuyimzc1gBJC2e.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>5 Days of War</th>
# ...

# %%
best_worst(5, "Votes")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %%
best_worst(5, "Average Rating", min_votes=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Planet Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//koVzjt54bJEVuKTmGC4cExcbE2w.jpg' style='height:100px;'></td>
#       <td>8.80</td>
#     </tr>
#     <tr>
#       <th>Sansho the Bailiff</th>
# ...

# %%
best_worst(5, "Average Rating", ascending=True, min_votes=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Manos: The Hands of Fate</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//dcDR1ZhZvA7HQvxQ17hzFjeCNHx.jpg' style='height:100px;'></td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>Birdemic: Shock and Terror</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lNC2Alq5CIIuPp1Bv0Y8hPHXZlP.jpg' style='height:100px;'></td>
#       <td>2.10</td>
#     </tr>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Back in the Day</th>
# ...

# %%
best_worst(5, "Average Rating", ascending=True, min_votes=20, min_bud=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>2.30</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
# ...

# %%
best_worst(5, "Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %%
# which mobie would you like to see next
df.genres[1]
mask_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor = df.cast.str.contains("Bruce Willis")
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
# combine both masks by movies which meet the condition and sort for yourself
df.loc[mask_actor & mask_genres, ["title", "vote_average"]].sort_values(by = "vote_average", ascending=False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 27619                   Vice          4.10

# %%
mask_actor & mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Length: 44691, dtype: bool

# %%
bruce = df.loc[mask_actor & mask_genres, ["title", "poster_path", "vote_average"]].sort_values(by = "vote_average", ascending=False)

# %%
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td>Surrogates</td>
# ...

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_director = df.director = "Quentin Tarantino"

# %%
mask_actor = df.cast.str.contains("Uma Thurman")

# %%
quentin = df.loc[mask_director & mask_actor, ["title", "poster_path", "runtime"]].sort_values(by = "runtime").set_index("title")

# %%
HTML(quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Gift</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//y4Q6EU7cLndLAFuDZZdNAD09hMU.jpg' style='height:100px;'></td>
#       <td>8.00</td>
#     </tr>
#     <tr>
#       <th>Jump!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lNI0HED58NOSAop4tR3PG9rg66X.jpg' style='height:100px;'></td>
#       <td>18.00</td>
#     </tr>
#     <tr>
#       <th>A Muppets Christmas: Letters to Santa</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1l3ngWFYUq31UtHDNvXxH3CDxNT.jpg' style='height:100px;'></td>
#       <td>55.00</td>
#     </tr>
#     <tr>
#       <th>Without Lying Down: Frances Marion and the Power of Women in Hollywood</th>
# ...

# %%
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 44686                                                  NaN
# 44687                                          Sine Olivia
# 44688                              American World Pictures
# 44689                                            Yermoliev
# 44690                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
mask_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 44686          NaT
# 44687   2011-11-17
# 44688   2003-08-01
# 44689   1917-10-21
# 44690   2017-06-09
# Name: release_date, Length: 44691, dtype: datetime64[ns]

# %%
mask_time = df.release_date.between("2010-01-01", "2015-12-31")

# %%
pixar = df.loc[mask_studio & mask_time, ["title", "poster_path", "revenue_musd", "release_date"]].sort_values(by="revenue_musd", ascending=False)

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15236</th>
#       <td>Toy Story 3</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>29957</th>
#       <td>Inside Out</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>20888</th>
#       <td>Monsters University</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %%
mask_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")

# %%
mask_lan = df.original_language == "en"

# %%
mask_vote_av = df.vote_average >= 7.5

# %%
mask_vote_co = df.vote_count >= 10

# %%
next_mov = df.loc[mask_genre & mask_lan & mask_vote_av & mask_vote_co, 
                  ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by="release_date", ascending=False).set_index("title").head(20)

# %%
HTML(next_mov.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>7.50</td>
#       <td>2712.00</td>
# ...

# %%
# most commonly used words in movie titles, taglines and overviews

# %%
from wordcloud import WordCloud

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df.title.dropna()
overview = df.overview.dropna()
tagline = df.tagline.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44686                         Subdue
# 44687            Century of Birthing
# 44688                       Betrayal
# 44689               Satan Triumphant
# 44690                       Queerama
# Name: title, Length: 44691, dtype: object

# %%
title_corpus = " ".join(title)
overview_corpus = " ".join(overview)
tagline_corpus = " ".join(tagline)

# %%
tagline_corpus
# Out:
# 'Roll the dice and unleash the excitement! Still Yelling. Still Fighting. Still Ready for Love. Friends are the people who let you be yourself... and never let you forget it. Just When His World Is Back To Normal... He\'s In For The Surprise Of His Life! A Los Angeles Crime Saga You are cordially invited to the most surprising merger of the year. The Original Bad Boys. Terror goes into overtime. No limits. No fears. No substitutes. Why can\'t the most powerful man in the world have the one thing he wants most? Part Dog. Part Wolf. All Hero. Triumphant in Victory, Bitter in Defeat. He Changed the World, But Lost a Nation. The Course Has Been Set. There Is No Turning Back. Prepare Your Weapons. Summon Your Courage. Discover the Adventure of a Lifetime! No one stays at the top forever. Lose your heart and come to your senses. Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who\'s in for the wildest New year\'s Eve of his life. New a
# ...

# %%
title_wordcloud = WordCloud(background_color="white", height=2000, width=4000, max_words=200).generate(title_corpus)
title_wordcloud

# %%
plt.figure(figsize=(16, 8))
plt.imshow(title_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# are franchises more successful? (ie movie collections)

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df["Franchise"] = df.belongs_to_collection.notna()

# %%
df.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
df.Franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %%
df.groupby("Franchise").revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %%
df["ROI"] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby("Franchise").ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %%
df.groupby("Franchise").budget_musd.mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %%
df.groupby("Franchise").popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %%
df.groupby("Franchise").vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %%
df.groupby("Franchise").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean"})
# Out:
#            budget_musd  revenue_musd  vote_average
# Franchise
# False            18.05         44.74          6.01
# True             38.32        165.71          5.96

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                    29
# Totò Collection                    27
# James Bond Collection              26
# Zatôichi: The Blind Swordsman      26
# The Carry On Collection            25
#                                    ..
# Skeleton Key Collection             1
# Detonator Collection                1
# Digimon Collection                  1
# Till Luck Do Us Part Collection     1
# Hopalong Cassidy films              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = df.groupby("belongs_to_collection").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean"})

# %%
franchises.nlargest(20, ("budget_musd"))
# Out:
#                                          budget_musd  revenue_musd  \
# belongs_to_collection
# Tangled Collection                            260.00        591.79
# Pirates of the Caribbean Collection           250.00        904.32
# The Avengers Collection                       250.00       1462.48
# The Hobbit Collection                         250.00        978.51
# Man of Steel Collection                       237.50        768.05
# Avatar Collection                             237.00       2787.97
# The Amazing Spider-Man Collection             207.50        728.97
# World War Z Collection                        200.00        531.87
# Spider-Man Collection                         199.00        832.12
# The Dark Knight Collection                    195.00        821.24
# Transformers Collection                       193.00        873.22
# Captain America Collection                    186.67        746.21
# The Chronicles of Narnia Collection           186.67        528.05
# ...

# %%
df.director
# Out:
# 0        Quentin Tarantino
# 1        Quentin Tarantino
# 2        Quentin Tarantino
# 3        Quentin Tarantino
# 4        Quentin Tarantino
#                ...
# 44686    Quentin Tarantino
# 44687    Quentin Tarantino
# 44688    Quentin Tarantino
# 44689    Quentin Tarantino
# 44690    Quentin Tarantino
# Name: director, Length: 44691, dtype: object

# %%
df.director.value_counts()
# Out:
# Quentin Tarantino    44691
# Name: director, dtype: int64

# %%
df.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44686              Leila Hatami|Kourosh Tahami|Elham Korda
# 44687    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44688    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44689    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.set_index("id", inplace=True)

# %%
df
# Out:
#                               title  \
# id
# 862                       Toy Story
# 8844                        Jumanji
# 15602              Grumpier Old Men
# 31357             Waiting to Exhale
# 11862   Father of the Bride Part II
# ...                             ...
# 439050                       Subdue
# 111109          Century of Birthing
# 67758                      Betrayal
# 227506             Satan Triumphant
# 461257                     Queerama
#
#                                                   tagline release_date  \
# id
# 862                                                   NaN   1995-10-30
# 8844            Roll the dice and unleash the excitement!   1995-12-15
# 15602   Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 31357   Friends are the people who let you be yourself...   1995-12-22
# 11862   Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                   ...          ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44691 entries, 862 to 461257
# Data columns (total 23 columns):
# title                    44691 non-null object
# tagline                  20284 non-null object
# release_date             44657 non-null datetime64[ns]
# genres                   42586 non-null object
# belongs_to_collection    4463 non-null object
# original_language        44681 non-null object
# budget_musd              8854 non-null float64
# revenue_musd             7385 non-null float64
# production_companies     33356 non-null object
# production_countries     38835 non-null object
# vote_count               44691 non-null float64
# vote_average             42077 non-null float64
# popularity               44691 non-null float64
# runtime                  43179 non-null float64
# overview                 43740 non-null object
# spoken_languages         41094 non-null object
# poster_path              44467 non-null object
# ...

# %%
df.cast.str.split("|")
# Out:
# id
# 862       [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 8844      [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 15602     [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 31357     [Whitney Houston, Angela Bassett, Loretta Devi...
# 11862     [Steve Martin, Diane Keaton, Martin Short, Kim...
#                                 ...
# 439050          [Leila Hatami, Kourosh Tahami, Elham Korda]
# 111109    [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 67758     [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 227506    [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 461257                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
act = df.cast.str.split("|", expand=True)

# %%
act
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
act.stack().reset_index(level=1, drop=True).to_frame(); # puts it vertically

# %%
act
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %% [markdown]
# ## Self-Coding

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("movies_complete.csv", parse_dates=["release_date"])

# %%
from IPython.display import HTML

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %%
def best_worst(by, n=5, ascending=False, min_budget=0, min_votes=0, custom_column=False):
    df2 = df.copy()
    
    if custom_column:
        df2[by] = custom_column(df2)
        
    df2 = df2.loc[(df["budget_musd"] >= min_budget) & (df["vote_count"] >= min_votes), ["title", "poster_path", by]].sort_values(by, ascending=ascending).head(5)
    
    df2.set_index("title", inplace=True)
    return HTML(df2.to_html(escape=False))

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst("revenue_musd")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst("budget_musd")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>budget_musd</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
def profit_musd(df):
    return  df["revenue_musd"].sub(df.budget_musd)

best_worst("profit_musd", custom_column=profit_musd)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>profit_musd</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst("profit_musd", custom_column=profit_musd, ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>profit_musd</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
def roi(df):
    return df.revenue_musd.div(df.budget_musd)

best_worst("roi", custom_column=roi, min_budget=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>roi</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst("roi", custom_column=roi, min_budget=50, ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>roi</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Metropolis</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3F5OKhpC6rqq5KdjgixNbqjWSWz.jpg' style='height:100px;'></td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Lolita</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//unGWuk8kax8r4PlbGJL9y6WnfFx.jpg' style='height:100px;'></td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Child 44</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qqGhMt31HVUN3WnH0L2r0OWq38E.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst("vote_count")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_count</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst("vote_average")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Time Pass</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eZXI0Od5sZXu1AhOSm4DhivbxkB.jpg' style='height:100px;'></td>
#       <td>10.00</td>
#     </tr>
#     <tr>
#       <th>Shuttlecock Boys</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6anA57vPp9vU2nCGSHgaqGmWIzR.jpg' style='height:100px;'></td>
#       <td>10.00</td>
#     </tr>
#     <tr>
#       <th>Forever</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRdh2UqLGcSUDNR53pi5MjjIHk1.jpg' style='height:100px;'></td>
#       <td>10.00</td>
#     </tr>
#     <tr>
#       <th>Souls of Zen: Ancestors and Agency in Contemporary Japanese Temple Buddhism</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst("vote_average", ascending=True, min_budget=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>2.30</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Gigli</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8zYn3dCOSXeoq9YOi4R6fFTHKXP.jpg' style='height:100px;'></td>
#       <td>3.50</td>
#     </tr>
#     <tr>
#       <th>Son of the Mask</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst("popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>popularity</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
df.genres
df.cast
genre_mask = df.genres.str.contains("Action")
actor_mask = df.cast.str.contains("Bruce Willis")

# %%
# combine both masks, then highlight colums you want and sort by vote average rating
df.loc[genre_mask & actor_mask, ["title", "vote_average"]].sort_values("vote_average", ascending=False)
# Out:
#                                  title  vote_average
# 998                           Die Hard          7.50
# 1448                 The Fifth Element          7.30
# 9813                          Sin City          7.20
# 162         Die Hard: With a Vengeance          6.90
# 19218                           Looper          6.60
# 1310                        Die Hard 2          6.60
# 15870                              RED          6.60
# 6795                The Last Boy Scout          6.50
# 11957                    Planet Terror          6.50
# 1786                        Armageddon          6.50
# 21093                            RED 2          6.40
# 6026                  Tears of the Sun          6.40
# 11837            Live Free or Die Hard          6.40
# 10736                        16 Blocks          6.20
# 4673                           Bandits          6.20
# 958                  Last Man Standing          6.20
# 2198                         The Siege          6.10
# ...

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
actor_mask = df.cast.str.contains("Uma Thurman")
director_mask = df.director.str.contains("Quentin Tarantino")

HTML(df.loc[actor_mask & director_mask, ["title", "poster_path", "runtime"]].sort_values("runtime").to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>37159</th>
#       <td>The Gift</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//y4Q6EU7cLndLAFuDZZdNAD09hMU.jpg' style='height:100px;'></td>
#       <td>8.00</td>
#     </tr>
#     <tr>
#       <th>37311</th>
#       <td>Jump!</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//lNI0HED58NOSAop4tR3PG9rg66X.jpg' style='height:100px;'></td>
#       <td>18.00</td>
#     </tr>
#     <tr>
#       <th>22075</th>
#       <td>A Muppets Christmas: Letters to Santa</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//1l3ngWFYUq31UtHDNvXxH3CDxNT.jpg' style='height:100px;'></td>
#       <td>55.00</td>
#     </tr>
#     <tr>
#       <th>25894</th>
#       <td>Without Lying Down: Frances Marion and the Power of Women in Hollywood</td>
# ...

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
# pandas data objects have a between method which is nifty
date_mask = df.release_date.between("2010-01-01", "2015-12-31")
date_studio = df.production_companies.str.contains("Pixar")

HTML(df.loc[date_mask & date_studio, ["title", "poster_path", "revenue_musd", "release_date"]].sort_values("revenue_musd", ascending=False).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15236</th>
#       <td>Toy Story 3</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>29957</th>
#       <td>Inside Out</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>20888</th>
#       <td>Monsters University</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
genre_mask = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")
lang_mask = df.original_language == "en"
vote_avg_mask = df.vote_average >= 7.5
vote_count_mask = df.vote_count >= 10

# %%
next_mov = df.loc[genre_mask & lang_mask & vote_avg_mask & vote_count_mask, ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by="release_date", ascending=False).head(20)

# %%
HTML(next_mov.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>44490</th>
#       <td>Descendants 2</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>43941</th>
#       <td>Dunkirk</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>7.50</td>
#       <td>2712.00</td>
#       <td>2017-07-19</td>
#     </tr>
#     <tr>
#       <th>42624</th>
# ...

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %%
df["Franchise"] = df.belongs_to_collection.notna()

# %%
df['Franchise'].value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.groupby("Franchise").revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df["ROI"] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby("Franchise").ROI.median() # don't blindly default to mean
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby("Franchise").budget_musd.mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby("Franchise").popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby("Franchise").vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
franchises = df.groupby("belongs_to_collection").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean"})

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                    29
# Totò Collection                    27
# James Bond Collection              26
# Zatôichi: The Blind Swordsman      26
# The Carry On Collection            25
#                                    ..
# Skeleton Key Collection             1
# Detonator Collection                1
# Digimon Collection                  1
# Till Luck Do Us Part Collection     1
# Hopalong Cassidy films              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises.nlargest(5, ("budget_musd"))
# Out:
#                                      budget_musd  revenue_musd  vote_average
# belongs_to_collection
# Tangled Collection                        260.00        591.79          7.25
# Pirates of the Caribbean Collection       250.00        904.32          6.88
# The Avengers Collection                   250.00       1462.48          7.35
# The Hobbit Collection                     250.00        978.51          7.23
# Man of Steel Collection                   237.50        768.05          6.10

# %%
franchises.nlargest(5, ("revenue_musd"))
# Out:
#                          budget_musd  revenue_musd  vote_average
# belongs_to_collection
# Avatar Collection             237.00       2787.97          7.20
# The Avengers Collection       250.00       1462.48          7.35
# Frozen Collection             150.00       1274.22          7.10
# Finding Nemo Collection       147.00        984.45          7.20
# The Hobbit Collection         250.00        978.51          7.23

# %%
franchises.nlargest(5, ("vote_average"))
# Out:
#                                      budget_musd  revenue_musd  vote_average
# belongs_to_collection
# Argo Collection                              nan           nan          9.30
# Bloodfight                                   nan           nan          9.00
# Dreileben                                    nan           nan          9.00
# Kenji Misumi's Trilogy of the Sword          nan           nan          9.00
# Алиса в стране чудес (Коллекция)             nan           nan          8.70

# %% [markdown]
# ## Most Successful Actors

# %%
df.set_index("id", inplace=True)

# %%
act = df.cast.str.split("|", expand=True)

# %%
act.stack()
# Out:
# id
# 862     0            Tom Hanks
#         1            Tim Allen
#         2          Don Rickles
#         3           Jim Varney
#         4        Wallace Shawn
#                    ...
# 227506  0     Iwan Mosschuchin
#         1    Nathalie Lissenko
#         2         Pavel Pavlov
#         3    Aleksandr Chabrov
#         4          Vera Orlova
# Length: 557703, dtype: object

# %%
act.stack().reset_index(level=1, drop=True)
# Out:
# id
# 862               Tom Hanks
# 862               Tim Allen
# 862             Don Rickles
# 862              Jim Varney
# 862           Wallace Shawn
#                 ...
# 227506     Iwan Mosschuchin
# 227506    Nathalie Lissenko
# 227506         Pavel Pavlov
# 227506    Aleksandr Chabrov
# 227506          Vera Orlova
# Length: 557703, dtype: object

# %%
act = act.stack().reset_index(level=1, drop=True).to_frame()

# %%
act.columns = ["Actor"]
act
# Out:
#                     Actor
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act = act.merge(df[["title", "revenue_musd", "vote_average", "popularity"]], how="left", left_index=True, right_index=True) # joins on the id

# %%
act
# Out:
#                      Actor                            title  revenue_musd  \
# id
# 2              Turo Pajala                            Ariel           nan
# 2         Susanna Haavisto                            Ariel           nan
# 2          Matti Pellonpää                            Ariel           nan
# 2             Eetu Hilkamo                            Ariel           nan
# 3          Matti Pellonpää              Shadows in Paradise           nan
# ...                    ...                              ...           ...
# 469172      Vasco Sequeira  Manuel on the Island of Wonders           nan
# 469172     Armanda Bacelar  Manuel on the Island of Wonders           nan
# 469172     Rafael de Sousa  Manuel on the Island of Wonders           nan
# 469172  José Antônio Gomes  Manuel on the Island of Wonders           nan
# 469172       Isabel Branco  Manuel on the Island of Wonders           nan
#
#         vote_average  popularity
# id
# 2               7.10        3.86
# ...

# %%
plt.figure(figsize=(12, 8))

act.Actor.value_counts().head(20).plot(kind="bar", fontsize=15)
plt.title("Most Active Actors", fontsize=20)
plt.ylabel("Number of Movies", fontsize=15)
plt.show()

# %%
agg = act.groupby("Actor").agg(Total_Revenue=("revenue_musd", "sum"), Mean_Revenue=("revenue_musd", "mean"), )

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__
